# %%
print("===============================================================================================================")
print("                                       Welcome to SmartAI Chatbot                                              ")
print("===============================================================================================================")
while True:
  user=input("User: ")
  chatbot=chatbot.lower()

  if chatbot == "Exit":
    print("Goodbye! Have a great day!")
    break
  elif "hello" in chatbot or "hi" in chatbot:
    print("Chatbot: Hello! I am a simple AI chatbot created using Python")
    print("Chatbot: Type 'menu' to see options or 'Exit' to quit the chatbot")
  user=input("User: ")
  print("Chatbot: Here are the available options:")
  print("\n Menu")
  print("1.What is Python?")
  print("2.What is AI?")
  print("3.What is ML?")
  print("4.Exit")
  choice = input("Enter your choice: ")
  if choice == "1":
    print("Chatbot: Python is a high level programming langauage used for web development, AI, and data science.")
  elif choice == "2":
    print("Chatbot: AI stands for Artificial Intelligence. It means machines that can think and respond like humans")
  elif choice == "3":
    print("Chatbot: Machine Learning is a part of AI that allows systems to learn from data. ")
  elif choice == "4":
    print("Chatbot:Thank you for using our chatbot. Goodbye!")
    break
  else:
    print("Chatbot:Sorry, I didn't understand that. Please try again.")
# Out:
# ===============================================================================================================
#                                        Welcome to SmartAI Chatbot
# ===============================================================================================================
# User: hi
# Chatbot: Hello! I am a simple AI chatbot created using Python
# Chatbot: Type 'menu' to see options or 'Exit' to quit the chatbot
# User: menu
# Chatbot: Here are the available options:
#
#  Menu
# 1.What is Python?
# 2.What is AI?
# 3.What is ML?
# 4.Exit
# Enter your choice: 3
# Chatbot: Machine Learning is a part of AI that allows systems to learn from data.
# User: 4
# Chatbot: Hello! I am a simple AI chatbot created using Python
# Chatbot: Type 'menu' to see options or 'Exit' to quit the chatbot
# User: mennu
# Chatbot: Here are the available options:
#
#  Menu
# 1.What is Python?
# 2.What is AI?
# 3.What is ML?
# 4.Exit
# Enter your choice: 4
# Chatbot:Thank you for using our chatbot. Goodbye!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Google Colab is available in VS Code!
# ![logo.webp](data:image/webp;base64,...)
#
# Try the new [Google Colab extension](https://marketplace.visualstudio.com/items?itemName=Google.colab) for Visual Studio Code. You can get up and running in just a few clicks:
#
# *  In VS Code, open the ***Extensions*** view and search for 'Google Colab' to install.
# *  Open the kernel selector by creating or opening any `.ipynb` notebook file in your local workspace and either running a cell or clicking the ***Select Kernel*** button in the top right.
# *  Click ***Colab*** and then select your desired runtime, sign in with your Google account, and you're all set!
#
# See more details in our [announcement blog here](https://developers.googleblog.com/google-colab-is-coming-to-vs-code).
